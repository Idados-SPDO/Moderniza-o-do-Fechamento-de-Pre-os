# %%
import pandas as pd

# %%
df_planilhao = pd.read_excel(r"W:\\Otimização e Automatização\\5. Projetos\\7. Sistema de Fechamento de Preços\\Modernização de Fechamento de Preço\\Ferramenta_outlier - Reestruturação\\importar\\ALIVAR_27.11.24.xlsx", header=7)
df_planilhao
# Out:
#                                               Elementar  \
# 0                                                   NaN
# 1                                                  9875
# 2                                                Insumo
# 3                                                   293
# 4                                                   293
# ...                                                 ...
# 2527                                             503401
# 2528                                             503401
# 2529                                                NaN
# 2530                                                NaN
# 2531  (*) Elementar correlacionado a indicador na re...
#
#                                    Descrição Unnamed: 2     Medida  \
# 0                                        NaN        NaN        NaN
# 1                              FÍGADO BOVINO        NaN         Kg
# 2                                  Descrição      Marca  Embalagem
# ...

# %%
validador = False
df_new = pd.DataFrame(columns=['Cód. Item Elementar', 'Desc. Item Elementar', 'Insinf/Cd Bases', 'Desc. Insinf', 'Sinônimo', 'Marca', 'Emb/Qtd', 
                               'Status Insinf', 'Cód Inf', 'Desc. Inf', 'Status Inf', 'Period', 'Preço Atual', 'Fator', 'Operador', 'Data Atual', 
                               'Preço Anterior', 'Preço Ref Anterior', 'Data Anterior', 'Tipo Preço', 'Região do preço', 'Reg. Ret.']) 

for i, j in df_planilhao.iterrows():
    if validador == False and isinstance(j['Elementar'], int):
        elementar = j['Elementar']
        descricao = j['Descrição']
        ref_anterior = j['Preço ant']
    if validador == True:
        new_row = [elementar, descricao, j['Unnamed: 6'], j['Descrição'], '-', j['Unnamed: 2'], j['Medida'], j['Unnamed: 7'],
                   j['Unnamed: 4'], j['Unnamed: 5'], j['Unnamed: 7'], j['Busca'], j['Cota perf.'], j['Usuário Aprovador'], j['Data Última Aprovação do Item'],
                   j['Cota util'], j['Unnamed: 28'], ref_anterior, j['Unnamed: 29'], j['Variação'], j['Nível'], '-']
        df_new.loc[len(df_new)] = new_row
    if 'Referência' in str(j['Elementar']):
        validador = False 
    if 'Insumo' in str(j['Elementar']):
        validador = True

df_new = df_new.dropna(subset=['Insinf/Cd Bases'])
df_new = df_new[df_new['Data Anterior'] != ' ']

df_new
# Out:
#       Cód. Item Elementar Desc. Item Elementar Insinf/Cd Bases  \
# 0                    9875        FÍGADO BOVINO       1523911.0
# 1                    9875        FÍGADO BOVINO          7854.0
# 2                    9875        FÍGADO BOVINO       1523640.0
# 3                    9875        FÍGADO BOVINO        704326.0
# 4                    9875        FÍGADO BOVINO       1522494.0
# ...                   ...                  ...             ...
# 2265               313030  AVEIA, FLOCOS FINOS         1560637
# 2266               313030  AVEIA, FLOCOS FINOS         1676860
# 2267               313030  AVEIA, FLOCOS FINOS         1558054
# 2268               313030  AVEIA, FLOCOS FINOS         1676872
# 2269               313030  AVEIA, FLOCOS FINOS         1676816
#
#                                 Desc. Insinf Sinônimo   Marca   Emb/Qtd  \
# 0     FIGADO DE BOVINO REFRIGERADO/CONGELADO        -     NaN        KG
# ...

# %%
df_new.to_excel(r"W:/Otimização e Automatização/5. Projetos/7. Sistema de Fechamento de Preços/Modernização de Fechamento de Preço/Ferramenta_outlier/data/planilhao_teste1.xlsx", index = False)
